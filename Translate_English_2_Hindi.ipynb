# %%
#! pip install googletrans

# %%
import googletrans
from googletrans import Translator
import os
import pandas as pd

# %%
#print(googletrans.LANGUAGES)

# %%
d = pd.read_csv('C:/Users/admin/Desktop/PDF2IMG/6.csv')

# %%
d.head()
# Out:
#        Assembly Constituency  Part Num                    Section  SNo  \
# 0  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   151
# 1  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   152
# 2  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   153
# 3  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   154
# 4  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   155
#
#         Voter ID                          Name      G_Relation  \
# 0  XQK0497678\n
#        Madatali Amirali Hemani   Father's Name
# 1  XQK0518144\n
#    Noorsultana Madatali Hemani  Husband's Name
# 2  XQK1680602\n
#      Noor Sultana Rehmattullah  Husband's Name
# 3  XQK1680594\n
#            Rahmatullah Ladhani  Father's Name
# 4  XQK1779008\n
#                 Sameera Gilani  Husband's Name
#
#                 Guardian               House_No  Age  Gender  \
# 0         Amirali Hemani                   5-8-   62    MALE
# ...

# %%
#translator = Translator()
b = []
for i in d['Name']:
    a = Translator().translate(i,src='en',dest='hi')
    a = a.text
    b.append(a)
    
d["Name"] = b

# %%
d.head()
# Out:
#        Assembly Constituency  Part Num                    Section  SNo  \
# 0  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   151
# 1  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   152
# 2  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   153
# 3  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   154
# 4  1-Gadwal Rani Compound\n
#         43  1-Gadwal Rani Compound\n
#   155
#
#         Voter ID                       Name      G_Relation  \
# 0  XQK0497678\n
#        मदताली अमीरली हेमानी   Father's Name
# 1  XQK0518144\n
#   नूरसुल्ताना मदालती हेमानी  Husband's Name
# 2  XQK1680602\n
#     नूर सुल्ताना रहमतुल्लाह  Husband's Name
# 3  XQK1680594\n
#             रहमतुल्लाह लधनी  Father's Name
# 4  XQK1779008\n
#                समीरा गिलानी  Husband's Name
#
#                 Guardian               House_No  Age  Gender  \
# 0         Amirali Hemani                   5-8-   62    MALE
# ...
